# %% [markdown]
# # Import libraries

# %%
import subprocess
from pathlib import Path
import pycolmap
import os
import shutil

# %% [markdown]
# # Functions

# %%
def clean_colmap(base_dir="assets"):
    """
    Recursively delete all COLMAP-generated files such as `pycolmap.db` 
    and `pycolmap_output/` directories from the given base directory.

    Parameters:
        base_dir (str): Root directory to start cleanup (default: 'assets')
    """
    for root, dirs, files in os.walk(base_dir):
        # Delete pycolmap.db files
        if "pycolmap.db" in files:
            db_path = os.path.join(root, "pycolmap.db")
            os.remove(db_path)
            print(f"Deleted file: {db_path}")

        # Delete pycolmap_output directories
        if "pycolmap_output" in dirs:
            output_path = os.path.join(root, "pycolmap_output")
            shutil.rmtree(output_path)
            print(f"Deleted directory: {output_path}")

# %%
def prepare_database_with_colmap(image_dir):
    image_dir = Path(image_dir)
    db_path = image_dir / "pycolmap.db"
    
    if db_path.exists():
        print("ℹ️ Removing existing database to force fresh extraction and matching.")
        db_path.unlink()
    # 1. Feature extraction
    subprocess.run([
        "colmap", "feature_extractor",
        "--database_path", str(db_path),
        "--image_path", str(image_dir)
    ], check=True)

    # 2. Feature matching
    subprocess.run([
        "colmap", "exhaustive_matcher",
        "--database_path", str(db_path)
    ], check=True)

    return db_path

def run_pycolmap_sfm_after_cli(image_dir):
    image_dir = Path(image_dir)
    db_path = prepare_database_with_colmap(image_dir)
    output_dir = image_dir / "pycolmap_output"
    output_dir.mkdir(exist_ok=True)

    reconstructions = pycolmap.incremental_mapping(
        database_path=str(db_path),
        image_path=str(image_dir),
        output_path=str(output_dir)
    )

    if not reconstructions:
        raise RuntimeError("❌ No reconstruction produced.")
    
    sfm = reconstructions[0]
    print("✅ SfM complete")
    print(f"Images registered: {len(sfm.images)}")
    print(f"3D points: {len(sfm.points3D)}")
    return sfm

# %%
clean_colmap()
# Out:
# Deleted file: assets/marine_noisy/pycolmap.db
# Deleted directory: assets/marine_noisy/pycolmap_output
# Deleted file: assets/marine/pycolmap.db
# Deleted directory: assets/marine/pycolmap_output

# %%
image_dir = "assets/marine"
db_path = f"{image_dir}/pycolmap.db"
subprocess.run([
    "colmap", "feature_extractor",
    "--database_path", str(db_path),
    "--image_path", str(image_dir)
], check=True)
# Out:
# QStandardPaths: wrong permissions on runtime directory /run/user/1000/, 0755 instead of 0700
# I20250715 18:12:51.563297 39293 misc.cc:198]
# ==============================================================================
# Feature extraction
# ==============================================================================
# I20250715 18:12:52.621860 39323 feature_extraction.cc:254] Processed file [1/22]
# I20250715 18:12:52.621906 39323 feature_extraction.cc:257]   Name:            Screenshot 2025-07-15 123438.png
# I20250715 18:12:52.621912 39323 feature_extraction.cc:283]   Dimensions:      2560 x 1600
# I20250715 18:12:52.621917 39323 feature_extraction.cc:286]   Camera:          #1 - SIMPLE_RADIAL
# I20250715 18:12:52.621938 39323 feature_extraction.cc:289]   Focal Length:    3072.00px
# I20250715 18:12:52.621953 39323 feature_extraction.cc:302]   Features:        5403
# I20250715 18:12:53.128152 39323 feature_extraction.cc:254] Processed file [2/22]
# I20250715 18:12:53.128202 39323 feature_extraction.cc:257]   Name:            Screenshot 2025-07-15 123455.png
# I20250715 18:12:53.128208 39323 feature_extraction.cc:283]   Dimensions:      2560 x 1600
# I20250715 18:12:53.128211 39323 feature_extraction.cc:286]   Camera:          #2 - SIMPLE_RADIAL
# I20250715 18:12:53.128216 39323 feature_extraction.cc:289]   Focal Length:    3072.00px
# I20250715 18:12
# I20250715 18:12:56.719226 39323 feature_extraction.cc:254] Processed file [22/22]
# I20250715 18:12:56.719229 39323 feature_extraction.cc:257]   Name:            pycolmap.db-wal
# E20250715 18:12:56.719233 39323 feature_extraction.cc:263] Failed to read image file format.
# I20250715 18:12:56.908008 39293 timer.cc:91] Elapsed time: 0.089 [minutes]
# CompletedProcess(args=['colmap', 'feature_extractor', '--database_path', 'assets/marine/pycolmap.db', '--image_path', 'assets/marine'], returncode=0)

# %%
sfm_result = run_pycolmap_sfm_after_cli("assets/marine")
# Out:
# ℹ️ Removing existing database to force fresh extraction and matching.
# QStandardPaths: wrong permissions on runtime directory /run/user/1000/, 0755 instead of 0700
# I20250715 17:11:23.194550 38229 misc.cc:198]
# ==============================================================================
# Feature extraction
# ==============================================================================
# I20250715 17:11:24.067042 38259 feature_extraction.cc:254] Processed file [1/22]
# I20250715 17:11:24.067085 38259 feature_extraction.cc:257]   Name:            Screenshot 2025-07-15 123438.png
# I20250715 17:11:24.067091 38259 feature_extraction.cc:283]   Dimensions:      2560 x 1600
# I20250715 17:11:24.067096 38259 feature_extraction.cc:286]   Camera:          #1 - SIMPLE_RADIAL
# I20250715 17:11:24.067101 38259 feature_extraction.cc:289]   Focal Length:    3072.00px
# I20250715 17:11:24.067116 38259 feature_extraction.cc:302]   Features:        5403
# I20250715 17:11:24.404017 38259 feature_extraction.cc:254] Processed file [2/22]
# I20250715 17:11:24.404062 38259 feature_extraction.cc:257]   Name:            Screenshot 2025-07-15 123455.png
# I20250715 17:11:24.404068 38259 feature_extraction.cc:283]   Dimensions:      2560 x 1600
# I20250715 17:11:24.404072 38259 feature_extraction.cc:286]   Camera:          #2 - SIMPLE_RADIAL
# I20250715 17:11:24.404078 38259 feature_extraction.cc:289]   Focal Length:    3072.00px
# I20250715 17:11:24.404085 38259 feature_extraction.cc:302]   Features:        5332
# I20250715 17:11:24.646394 38259 feature_extraction.cc:254] Processed file [3/22]
# I20250715 17:11:24.646440 38259 feature_extraction.cc:257]   Name:            Screenshot 2025-07-15 123512.png
# I20250715 17:11:24.646445 38259 feature_extraction.cc:283]   Dimensions:      2560 x 1600
# I20250715 17:11:24.646448 38259 feature_extraction.cc:286]   Camera:          #3 - SIMPLE_RADIAL
# I20250715 17:11:24.646452 38259 feature_extraction.cc:289]   Focal Length:    3072.00px
# I20250715 17:11:24.646461 38259 feature_extraction.cc:302]   Features:        4885
# I20250715 17:11:24.889034 38259 feature_extraction.cc:254] Processed file [4/22]
# I20250715 17:11:24.889079 38259 feature_extraction.cc:257]   Name:            Screenshot 2025-07-15 123535.png
# I20250715 17:11:24.889086 38259 feature_extraction.cc:283]   Dimensions:      2560 x 1600
# I20250715 17:11:24.889089 38259 feature_extraction.cc:286]   Camera:          #4 - SIMPLE_RADIAL
# I20250715 17:11:24.889093 38259 feature_extraction.cc:289]   Focal Length:    3072.00px
# I20250715 17:11:24.889101 38259 feature_extraction.cc:302]   Features:        4778
# I20250715 17:11:25.131114 38259 feature_extraction.cc:254] Processed file [5/22]
# I20250715 17:11:25.131157 38259 feature_extraction.cc:257]   Name:            Screenshot 2025-07-15 123552.png
# I20250715 17:11:25.131163 38259 feature_extraction.cc:283]   Dimensions:      2560 x 1600
# I20250715 17:11:25.131167 38259 feature_extraction.cc:286]   Camera:          #5 - SIMPLE_RADIAL
# I20250715 17:11:25.131171 38259 feature_extraction.cc:289]   Focal Length:    3072.00px
# I20250715 17:11:25.131178 38259 feature_extraction.cc:302]   Features:        4901
# I20250715 17:11:25.475579 38259 feature_extraction.cc:254] Processed file [6/22]
# I20250715 17:11:25.475637 38259 feature_extraction.cc:257]   Name:            Screenshot 2025-07-15 123609.png
# I20250715 17:11:25.475644 38259 feature_extraction.cc:283]   Dimensions:      2560 x 1600
# I20250715 17:11:25.475647 38259 feature_extraction.cc:286]   Camera:          #6 - SIMPLE_RADIAL
# I20250715 17:11:25.475652 38259 feature_extraction.cc:289]   Focal Length:    3072.00px
# I20250715 17:11:25.475661 38259 feature_extraction.cc:302]   Features:        4771
# I20250715 17:11:25.763237 38259 feature_extraction.cc:254] Processed file [7/22]
# I20250715 17:11:25.763283 38259 feature_extraction.cc:257]   Name:            Screenshot 2025-07-15 123626.png
# I20250715 17:11:25.763288 38259 feature_extraction.cc:283]   Dimensions:      2560 x 1600
# I20250715 17:11:25.763293 38259 feature_extraction.cc:286]   Camera:          #7 - SIMPLE_RADIAL
# I20250715 17:11:25.763296 38259 feature_extraction.cc:289]   Focal Length:    3072.00px
# I20250715 17:11
38259 feature_extraction.cc:257]   Name:            Screenshot 2025-07-15 124552.png
# I20250715 17:11:28.388365 38259 feature_extraction.cc:283]   Dimensions:      2560 x 1600
# I20250715 17:11:28.388368 38259 feature_extraction.cc:286]   Camera:          #17 - SIMPLE_RADIAL
# I20250715 17:11:28.388372 38259 feature_extraction.cc:289]   Focal Length:    3072.00px
# I20250715 17:11:28.388379 38259 feature_extraction.cc:302]   Features:        3940
# I20250715 17:11:28.620433 38259 feature_extraction.cc:254] Processed file [18/22]
# I20250715 17:11:28.620477 38259 feature_extraction.cc:257]   Name:            Screenshot 2025-07-15 124605.png
# I20250715 17:11:28.620483 38259 feature_extraction.cc:283]   Dimensions:      2560 x 1600
# I20250715 17:11:28.620486 38259 feature_extraction.cc:286]   Camera:          #18 - SIMPLE_RADIAL
# I20250715 17:11:28.620491 38259 feature_extraction.cc:289]   Focal Length:    3072.00px
# I20250715 17:11:28.620497 38259 feature_extraction.cc:302]   Features:        3969
# I20250715 17:11:28.891137 38259 feature_extraction.cc:254] Processed file [19/22]
# I20250715 17:11:28.891180 38259 feature_extraction.cc:257]   Name:            Screenshot 2025-07-15 124636.png
# I20250715 17:11:28.891187 38259 feature_extraction.cc:283]   Dimensions:      2560 x 1600
# I20250715 17:11:28.891193 38259 feature_extraction.cc:286]   Camera:          #19 - SIMPLE_RADIAL
# I20250715 17:11:28.891199 38259 feature_extraction.cc:289]   Focal Length:    3072.00px
# I20250715 17:11:28.891207 38259 feature_extraction.cc:302]   Features:        4700
# I20250715 17:11:28.891659 38259 feature_extraction.cc:254] Processed file [20/22]
# I20250715 17:11:28.891677 38259 feature_extraction.cc:257]   Name:            pycolmap.db
# E20250715 17:11:28.891683 38259 feature_extraction.cc:263] Failed to read image file format.
# I20250715 17:11:28.891695 38259 feature_extraction.cc:254] Processed file [21/22]
# I20250715 17:11:28.891700 38259 feature_extraction.cc:257]   Name:            pycolmap.db-shm
# E20250715 17:11:28.891705 38259 feature_extraction.cc:263] Failed to read image file format.
# I20250715 17:11:28.891708 38259 feature_extraction.cc:254] Processed file [22/22]
# I20250715 17:11:28.891711 38259 feature_extraction.cc:257]   Name:            pycolmap.db-wal
# E20250715 17:11:28.891719 38259 feature_extraction.cc:263] Failed to read image file format.
# I20250715 17:11:29.055984 38229 timer.cc:91] Elapsed time: 0.098 [minutes]
# QStandardPaths: wrong permissions on runtime directory /run/user/1000/, 0755 instead of 0700
# I20250715 17:11:29.252238 38271 misc.cc:198]
# ==============================================================================
# Exhaustive feature matching
# ==============================================================================
# I20250715 17:11:29.290012 38271 feature_matching.cc:231] Matching block [1/1, 1/1]
# I20250715 17:11:43.297652 38271 feature_matching.cc:46]  in 14.008s
# I20250715 17:11:43.300557 38271 timer.cc:91] Elapsed time: 0.234 [minutes]
# I20250715 17:11:43.334446 138594054647424 incremental_pipeline.cc:253] Loading database
# I20250715 17:11:43.335382 138594054647424 database_cache.cc:66] Loading rigs...
# I20250715 17:11:43.335414 138594054647424 database_cache.cc:76]  0 in 0.000s
# I20250715 17:11:43.335421 138594054647424 database_cache.cc:84] Loading cameras...
# I20250715 17:11:43.335435 138594054647424 database_cache.cc:102]  19 in 0.000s
# I20250715 17:11:43.335437 138594054647424 database_cache.cc:110] Loading frames...
# I20250715 17:11:43.335439 138594054647424 database_cache.cc:127]  0 in 0.000s
# I20250715 17:11:43.335440 138594054647424 database_cache.cc:135] Loading matches...
# I20250715 17:11:43.335996 138594054647424 database_cache.cc:140]  171 in 0.001s
# I20250715 17:11:43.336150 138594054647424 database_cache.cc:156] Loading images...
# I20250715 17:11:43.337386 138594054647424 database_cache.cc:241]  19 in 0.001s (connected 19)
# I20250715 17:11:43.337411 138594054647424 database_cache.cc:252] Building correspondence graph...
# I20250715 17:11:43.343080 138594054647424 database_cache.cc:279]  in 0.006s (ignored 0)
# I20250715 17:11:43.343121 138594054647424 timer.cc:91] Elapsed time: 0.000 [minutes]
# I20250715 17:11:43.343629 138594054647424 incremental_pipeline.cc:299] Finding good initial image pair
# I20250715 17:11:43.699346 138594054647424 incremental_pipeline.cc:303] => No good initial image pair found.
# I20250715 17:11:43.699380 138594054647424 incremental_pipeline.cc:544] Discarding reconstruction due to no initial pair
# I20250715 17:11:43.699409 138594054647424 incremental_pipeline.cc:234] => Relaxing the initialization constraints.
# I20250715 17:11:43.699740 138594054647424 incremental_pipeline.cc:299] Finding good initial image pair
# I20250715 17:11:44.049679 138594054647424 incremental_pipeline.cc:303] => No good initial image pair found.
# I20250715 17:11:44.049717 138594054647424 incremental_pipeline.cc:544] Discarding reconstruction due to no initial pair
# I20250715 17:11:44.049751 138594054647424 incremental_pipeline.cc:243] => Relaxing the initialization constraints.
# I20250715 17:11:44.050238 138594054647424 incremental_pipeline.cc:299] Finding good initial image pair
# I20250715 17:11:44.404659 138594054647424 incremental_pipeline.cc:303] => No good initial image pair found.
# I20250715 17:11:44.404693 138594054647424 incremental_pipeline.cc:544] Discarding reconstruction due to no initial pair
# I20250715 17:11:44.404725 138594054647424 incremental_pipeline.cc:234] => Relaxing the initialization constraints.
# I20250715 17:11:44.405018 138594054647424 incremental_pipeline.cc:299] Finding good initial image pair
# I20250715 17:11:44.742606 138594054647424 incremental_pipeline.cc:303] => No good initial image pair found.
# I20250715 17:11:44.742639 138594054647424 incremental_pipeline.cc:544] Discarding reconstruction due to no initial pair
# I20250715 17:11:44.742670 138594054647424 incremental_pipeline.cc:243] => Relaxing the initialization constraints.
# I20250715 17:11:44.743042 138594054647424 incremental_pipeline.cc:299] Finding good initial image pair
# I20250715 17:11:45.095139 138594054647424 incremental_pipeline.cc:303] => No good initial image pair found.
# I20250715 17:11:45.095176 138594054647424 incremental_pipeline.cc:544] Discarding reconstruction due to no initial pair
# I20250715 17:11:45.095216 138594054647424 timer.cc:91] Elapsed time: 0.029 [minutes]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sfm_result = run_pycolmap_sfm_after_cli("assets/marine")
#
# Cell In[8], line 36, in run_pycolmap_sfm_after_cli(image_dir)
#      29 reconstructions = pycolmap.incremental_mapping(
#      30     database_path=str(db_path),
#      31     image_path=str(image_dir),
#      32     output_path=str(output_dir)
#      33 )
#      35 if not reconstructions:
# ---> 36     raise RuntimeError("❌ No reconstruction produced.")
#      38 sfm = reconstructions[0]
#      39 print("✅ SfM complete")
#
# RuntimeError: ❌ No reconstruction produced.

# %%
sfm_result.visualize()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sfm_result.visualize()
#
# AttributeError: 'pycolmap._core.Reconstruction' object has no attribute 'visualize'
